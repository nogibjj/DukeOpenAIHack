# %%
from nba_api.stats.endpoints import playbyplayv2

# Replace '0021900017' with your game ID
game_id = "0021900017"

# Get the play-by-play data
pbp = playbyplayv2.PlayByPlayV2(game_id)

# Convert to a DataFrame
df = pbp.get_data_frames()[0]
list(df["HOMEDESCRIPTION"])
# Out:
# [None,
#  'Jump Ball Theis vs. Gasol: Tip to VanVleet',
#  None,
#  'Theis REBOUND (Off:0 Def:1)',
#  "MISS Theis 4' Driving Floating Jump Shot",
#  'Theis REBOUND (Off:1 Def:1)',
#  "MISS Theis 4' Layup",
#  None,
#  None,
#  None,
#  'Brown Driving Layup (2 PTS) (Theis 1 AST)',
#  None,
#  "Hayward 25' 3PT Jump Shot (3 PTS) (Brown 1 AST)",
#  None,
#  'Brown REBOUND (Off:0 Def:1)',
#  "Brown 5' Driving Floating Jump Shot (4 PTS)",
#  'Walker S.FOUL (P1.T1) (M.Smith)',
#  None,
#  None,
#  "MISS Tatum 14' Fadeaway Jumper",
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Tatum STEAL (1 STL)',
#  "Brown 1' Driving Layup (6 PTS) (Tatum 1 AST)",
#  None,
#  'Hayward REBOUND (Off:0 Def:1)',
#  'MISS Walker Driving Layup',
#  None,
#  'Theis P.FOUL (P1.T2) (E.Malloy)',
#  'Theis Violation:Kicked Ball (M.Smith)',
#  'Brown S.FOUL (P1.T3) (D.Richardson)',
#  None,
#  None,
#  'SUB: Williams III FOR Theis',
#  None,
#  "MISS Walker 25' 3PT Pullup Jump Shot",
#  None,
#  None,
#  'Walker Out of Bounds - Bad Pass Turnover Turnover (P1.T1)',
#  None,
#  'Williams III REBOUND (Off:0 Def:1)',
#  "MISS Brown 10' Driving Floating Jump Shot",
#  'Williams III REBOUND (Off:1 Def:1)',
#  "Williams III 1' Tip Layup Shot (2 PTS)",
#  None,
#  'Tatum REBOUND (Off:0 Def:1)',
#  "MISS Tatum 17' Driving Floating Jump Shot",
#  'Tatum REBOUND (Off:1 Def:1)',
#  "MISS Walker 10' Driving Floating Jump Shot",
#  None,
#  None,
#  'Williams III REBOUND (Off:1 Def:2)',
#  None,
#  'CELTICS Timeout: Regular (Full 1 Short 0)',
#  'SUB: Smart FOR Tatum',
#  'Hayward Free Throw 1 of 2 (4 PTS)',
#  'Hayward Free Throw 2 of 2 (5 PTS)',
#  None,
#  "MISS Walker 15' Driving Floating Jump Shot",
#  'Walker REBOUND (Off:1 Def:0)',
#  'MISS Walker Layup',
#  None,
#  None,
#  None,
#  None,
#  'SUB: Williams FOR Brown',
#  'Hayward OFF.Foul (P1) (D.Richardson)',
#  'Hayward Offensive Foul Turnover (P1.T2)',
#  'Smart STEAL (1 STL)',
#  "MISS Hayward 11' Fadeaway Jumper",
#  None,
#  'Williams P.FOUL (P1.T4) (E.Malloy)',
#  None,
#  None,
#  None,
#  "MISS Walker 15' Pullup Jump Shot",
#  'Williams III REBOUND (Off:2 Def:2)',
#  "MISS Smart 26' 3PT Jump Shot",
#  'Williams REBOUND (Off:1 Def:0)',
#  "MISS Williams 1' Reverse Layup",
#  None,
#  None,
#  None,
#  'SUB: Ojeleye FOR Williams III',
#  None,
#  "Walker 1' Cutting Layup Shot (2 PTS) (Williams 1 AST)",
#  None,
#  'Hayward Lost Ball Turnover (P2.T3)',
#  'Hayward P.FOUL (P2.PN) (D.Richardson)',
#  None,
#  None,
#  'Ojeleye REBOUND (Off:0 Def:1)',
#  None,
#  "Smart 10' Driving Floating Jump Shot (2 PTS)",
#  'Walker BLOCK (1 BLK)',
#  'Smart REBOUND (Off:0 Def:1)',
#  None,
#  None,
#  'SUB: Tatum FOR Hayward',
#  "MISS Walker 25' 3PT Fadeaway Jumper",
#  'Williams REBOUND (Off:2 Def:0)',
#  "Tatum 14' Floating Jump Shot (2 PTS) (Williams 2 AST)",
#  None,
#  "MISS Tatum 16' Driving Floating Jump Shot",
#  None,
#  None,
#  'Tatum REBOUND (Off:1 Def:2)',
#  "Tatum 26' 3PT Jump Shot (5 PTS) (Williams 3 AST)",
#  None,
#  None,
#  'SUB: Brown FOR Walker',
#  None,
#  None,
#  "MISS Tatum 1' Driving Layup",
#  None,
#  None,
#  'Brown REBOUND (Off:0 Def:2)',
#  "MISS Tatum 25' 3PT Jump Shot",
#  None,
#  None,
#  'Brown REBOUND (Off:0 Def:3)',
#  "MISS Williams 25' 3PT Jump Shot",
#  None,
#  None,
#  'Tatum REBOUND (Off:1 Def:3)',
#  None,
#  None,
#  "Tatum 1' Cutting Dunk Shot (7 PTS) (Smart 1 AST)",
#  None,
#  'Theis REBOUND (Off:1 Def:2)',
#  "MISS Smart 26' 3PT Jump Shot",
#  None,
#  None,
#  "MISS Wanamaker 26' 3PT Jump Shot",
#  None,
#  None,
#  "MISS Tatum 1' Driving Layup",
#  'CELTICS Rebound',
#  None,
#  "MISS Theis 2' Cutting Layup Shot",
#  None,
#  'Tatum STEAL (2 STL)',
#  None,
#  None,
#  "MISS Smart 25' 3PT Jump Shot",
#  None,
#  'Wanamaker STEAL (1 STL)',
#  "MISS Wanamaker 2' Running Layup",
#  'Tatum REBOUND (Off:2 Def:3)',
#  None,
#  'Wanamaker Free Throw 1 of 2 (1 PTS)',
#  'Wanamaker Free Throw 2 of 2 (2 PTS)',
#  None,
#  "MISS Brown 15' Pullup Jump Shot",
#  'Theis REBOUND (Off:2 Def:2)',
#  None,
#  'Theis Free Throw 1 of 2 (1 PTS)',
#  'MISS Theis Free Throw 2 of 2',
#  None,
#  None,
#  "MISS Tatum 2' Driving Finger Roll Layup",
#  'Wanamaker REBOUND (Off:1 Def:0)',
#  "Wanamaker 2' Putback Layup (4 PTS)",
#  None,
#  'Wanamaker REBOUND (Off:1 Def:1)',
#  'CELTICS Timeout: Regular (Full 2 Short 0)',
#  'SUB: Hayward FOR Theis',
#  'SUB: Williams III FOR Smart',
#  "Brown 8' Driving Layup (8 PTS)",
#  None,
#  None,
#  'Brown Free Throw 1 of 1 (9 PTS)',
#  'Wanamaker P.FOUL (P1.T1) (E.Malloy)',
#  None,
#  'Brown REBOUND (Off:0 Def:4)',
#  "MISS Tatum 17' Pullup Jump Shot",
#  None,
#  'Williams III STEAL (1 STL)',
#  "Tatum 1' Driving Layup (9 PTS)",
#  None,
#  'Williams III Traveling Turnover (P1.T4)',
#  None,
#  None,
#  'Tatum STEAL (3 STL)',
#  'Brown Driving Dunk (11 PTS) (Tatum 2 AST)',
#  'Williams III STEAL (2 STL)',
#  'Wanamaker Out of Bounds - Bad Pass Turnover Turnover (P1.T5)',
#  None,
#  'Williams III REBOUND (Off:2 Def:3)',
#  "Williams III 1' Alley Oop Dunk (4 PTS) (Hayward 1 AST)",
#  None,
#  'SUB: Walker FOR Wanamaker',
#  None,
#  'Williams III REBOUND (Off:2 Def:4)',
#  "MISS Tatum 26' 3PT Jump Shot",
#  None,
#  None,
#  'Brown Bad Pass Turnover (P1.T6)',
#  None,
#  "MISS Walker 25' 3PT Pullup Jump Shot",
#  None,
#  'Brown P.FOUL (P2.T2) (M.Smith)',
#  'SUB: Smart FOR Tatum',
#  'SUB: Williams FOR Williams III',
#  'Walker BLOCK (2 BLK)',
#  'Hayward REBOUND (Off:0 Def:2)',
#  "MISS Brown 7' Layup",
#  'Hayward REBOUND (Off:1 Def:2)',
#  "MISS Hayward 1' Tip Layup Shot",
#  None,
#  None,
#  'Walker Traveling Turnover (P2.T7)',
#  None,
#  "MISS Brown 25' 3PT Jump Shot",
#  None,
#  None,
#  'Brown REBOUND (Off:0 Def:5)',
#  "Brown 11' Fadeaway Jumper (13 PTS)",
#  None,
#  'Smart S.FOUL (P1.T3) (E.Malloy)',
#  None,
#  None,
#  "MISS Williams 3' Cutting Finger Roll Layup Shot",
#  None,
#  'Williams STEAL (1 STL)',
#  "Smart 5' Driving Hook Shot (4 PTS)",
#  'Walker STEAL (1 STL)',
#  None,
#  'Walker Free Throw 1 of 2 (3 PTS)',
#  'SUB: Tatum FOR Brown',
#  'Walker Free Throw 2 of 2 (4 PTS)',
#  None,
#  'Tatum REBOUND (Off:2 Def:4)',
#  "Hayward 17' Pullup Jump Shot (7 PTS)",
#  None,
#  None,
#  "MISS Hayward 15' Turnaround Fadeaway Shot",
#  'Williams REBOUND (Off:3 Def:0)',
#  "Williams 1' Tip Layup Shot (2 PTS)",
#  None,
#  None,
#  'Tatum Free Throw 1 of 2 (10 PTS)',
#  'SUB: Wanamaker FOR Walker',
#  'SUB: Green FOR Hayward',
#  None,
#  'Tatum Free Throw 2 of 2 (11 PTS)',
#  'Wanamaker Personal Take Foul (P2.T4) (E.Malloy)',
#  'CELTICS Timeout: Coach Challenge (Full 2 Short 0)',
#  None,
#  'Jump Ball (CC) Williams vs. Gasol: Tip to Smart',
#  None,
#  None,
#  None,
#  "MISS Tatum 16' Pullup Jump Shot",
#  None,
#  'Theis BLOCK (1 BLK)',
#  'Tatum REBOUND (Off:2 Def:5)',
#  "Hayward 26' 3PT Jump Shot (10 PTS) (Brown 2 AST)",
#  None,
#  "MISS Theis 27' 3PT Jump Shot",
#  None,
#  None,
#  "Walker 15' Pullup Jump Shot (6 PTS)",
#  None,
#  'Brown REBOUND (Off:0 Def:6)',
#  "MISS Walker 25' 3PT Step Back Jump Shot",
#  None,
#  None,
#  None,
#  'CELTICS T.Foul (Def. 3 Sec Brown ) (D.Richardson)',
#  None,
#  'Theis BLOCK (2 BLK)',
#  'CELTICS Rebound',
#  None,
#  "Brown 5' Driving Layup (15 PTS)",
#  None,
#  "MISS Theis 5' Cutting Layup Shot",
#  None,
#  'Walker STEAL (2 STL)',
#  "MISS Tatum 5' Cutting Layup Shot",
#  'Theis REBOUND (Off:3 Def:2)',
#  "MISS Theis 2' Putback Layup",
#  None,
#  None,
#  None,
#  'Hayward Out of Bounds - Bad Pass Turnover Turnover (P3.T8)',
#  None,
#  "Walker 2' Driving Finger Roll Layup (8 PTS)",
#  None,
#  'Brown REBOUND (Off:0 Def:7)',
#  None,
#  'SUB: Williams III FOR Theis',
#  "MISS Brown 26' 3PT Jump Shot",
#  None,
#  'Williams III L.B.FOUL (P1.T1) (E.Malloy)',
#  None,
#  "Brown 6' Turnaround Fadeaway (17 PTS)",
#  'Williams III BLOCK (1 BLK)',
#  'Walker REBOUND (Off:1 Def:1)',
#  "MISS Hayward 9' Driving Layup",
#  None,
#  None,
#  'Williams III S.FOUL (P2.T2) (E.Malloy)',
#  'CELTICS Timeout: Regular (Full 3 Short 0)',
#  'SUB: Smart FOR Hayward',
#  None,
#  'MISS Tatum 3PT Jump Shot',
#  None,
#  None,
#  "Brown 25' 3PT Jump Shot (20 PTS) (Williams III 1 AST)",
#  None,
#  None,
#  None,
#  "MISS Smart 24' 3PT Jump Shot",
#  'Tatum REBOUND (Off:3 Def:5)',
#  "Tatum 3' Driving Layup (13 PTS)",
#  None,
#  'Williams III S.FOUL (P3.T3) (E.Malloy)',
#  'SUB: Williams FOR Brown',
#  'SUB: Theis FOR Williams III',
#  None,
#  "MISS Williams 26' 3PT Jump Shot",
#  None,
#  'Theis P.FOUL (P2.T4) (M.Smith)',
#  None,
#  'Theis REBOUND (Off:3 Def:3)',
#  "MISS Tatum 5' Running Layup",
#  'Williams REBOUND (Off:4 Def:0)',
#  "MISS Williams 1' Tip Layup Shot",
#  None,
#  None,
#  'CELTICS Rebound',
#  None,
#  "Tatum 26' 3PT Jump Shot (16 PTS) (Smart 2 AST)",
#  None,
#  "Walker 25' 3PT Pullup Jump Shot (11 PTS)",
#  None,
#  None,
#  'Tatum REBOUND (Off:3 Def:6)',
#  "MISS Tatum 3' Driving Layup",
#  'CELTICS Rebound',
#  None,
#  'Tatum Free Throw 1 of 1 (17 PTS)',
#  "MISS Smart 9' Floating Jump Shot",
#  None,
#  None,
#  None,
#  'SUB: Hayward FOR Walker',
#  "MISS Theis 7' Turnaround Jump Shot",
#  'Williams REBOUND (Off:5 Def:0)',
#  'Tatum 3PT Jump Shot (20 PTS) (Williams 4 AST)',
#  None,
#  'MISS Williams 3PT Jump Shot',
#  None,
#  'Theis L.B.FOUL (P3.PN) (D.Richardson)',
#  None,
#  None,
#  'Williams REBOUND (Off:5 Def:1)',
#  'SUB: Brown FOR Tatum',
#  'SUB: Wanamaker FOR Theis',
#  'MISS Hayward Alley Oop Layup',
#  None,
#  None,
#  "MISS Hayward 25' 3PT Jump Shot",
#  None,
#  None,
#  None,
#  None,
#  'Brown REBOUND (Off:0 Def:8)',
#  "MISS Smart 5' Driving Floating Jump Shot",
#  'Williams REBOUND (Off:6 Def:1)',
#  "MISS Williams 1' Tip Layup Shot",
#  None,
#  'Wanamaker BLOCK (1 BLK)',
#  None,
#  None,
#  'Wanamaker REBOUND (Off:1 Def:2)',
#  "Smart 24' 3PT Jump Shot (7 PTS) (Brown 3 AST)",
#  None,
#  "Smart 26' 3PT Pullup Jump Shot (10 PTS)",
#  None,
#  "MISS Smart 26' 3PT Jump Shot",
#  None,
#  None,
#  'CELTICS Timeout: Regular (Full 4 Short 0)',
#  "MISS Brown 24' 3PT Jump Shot",
#  None,
#  None,
#  'SUB: Walker FOR Wanamaker',
#  'SUB: Williams III FOR Williams',
#  None,
#  "Walker 14' Pullup Jump Shot (13 PTS)",
#  'Williams III P.FOUL (P4.T1) (D.Richardson)',
#  None,
#  None,
#  None,
#  "Walker 26' 3PT Pullup Jump Shot (16 PTS)",
#  None,
#  'Hayward REBOUND (Off:1 Def:3)',
#  "MISS Brown 18' Pullup Jump Shot",
#  None,
#  'Walker S.FOUL (P2.T2) (E.Malloy)',
#  None,
#  None,
#  None,
#  "Walker 3' Driving Layup (18 PTS)",
#  None,
#  "Williams III 4' Alley Oop Layup (6 PTS) (Smart 3 AST)",
#  None,
#  "Walker 2' Driving Layup (20 PTS)",
#  None,
#  "MISS Walker 2' Driving Layup",
#  'Walker REBOUND (Off:2 Def:1)',
#  None,
#  'Walker Free Throw 1 of 2 (21 PTS)',
#  'SUB: Tatum FOR Smart',
#  None,
#  'SUB: Williams FOR Williams III',
#  'Walker Free Throw 2 of 2 (22 PTS)',
#  'Brown BLOCK (1 BLK)',
#  None,
#  None,
#  'Hayward REBOUND (Off:1 Def:4)',
#  "Brown 1' Driving Layup (22 PTS) (Hayward 2 AST)",
#  None,
#  None,
#  'Walker REBOUND (Off:2 Def:2)',
#  "Hayward 2' Cutting Layup Shot (12 PTS) (Brown 4 AST)",
#  None,
#  None,
#  None,
#  "Williams 2' Cutting Layup Shot (4 PTS) (Walker 1 AST)",
#  None,
#  None,
#  'Williams OFF.Foul (P2) (M.Smith)',
#  'Williams Offensive Foul Turnover (P1.T9)',
#  'Brown BLOCK (2 BLK)',
#  'Walker REBOUND (Off:2 Def:3)',
#  "Tatum 25' 3PT Jump Shot (23 PTS) (Walker 2 AST)",
#  'Williams P.FOUL (P3.T3) (E.Malloy)',
#  None,
#  "MISS Walker 26' 3PT Pullup Jump Shot",
#  None,
#  None,
#  'CELTICS Timeout: Regular (Full 5 Short 0)',
#  None,
#  "Hayward 26' 3PT Jump Shot (15 PTS) (Tatum 3 AST)",
#  'Walker S.FOUL (P3.T4) (E.Malloy)',
#  None,
#  None,
#  "Brown 24' 3PT Jump Shot (25 PTS) (Tatum 4 AST)",
#  None,
#  'Brown REBOUND (Off:0 Def:9)',
#  "MISS Walker 27' 3PT Jump Shot",
#  None,
#  None,
#  'Hayward REBOUND (Off:1 Def:5)',
#  "MISS Walker 7' Driving Floating Jump Shot",
#  None,
#  'SUB: Smart FOR Williams',
#  None,
#  None,
#  None,
#  None,
#  "MISS Brown 26' 3PT Jump Shot",
#  'Walker REBOUND (Off:3 Def:3)',
#  "MISS Brown 28' 3PT Jump Shot",
#  'CELTICS Rebound',
#  'CELTICS Turnover: Shot Clock (T#10)',
#  None,
#  "MISS Walker 12' Driving Floating Jump Shot",
#  'Hayward REBOUND (Off:2 Def:5)',
#  "MISS Hayward 1' Tip Layup Shot",
#  'Hayward REBOUND (Off:3 Def:5)',
#  None,
#  None,
#  None,
#  None,
#  'Tatum Free Throw 1 of 2 (24 PTS)',
#  'Tatum Free Throw 2 of 2 (25 PTS)',
#  None,
#  None,
#  None,
#  None]

# %%
df.columns
# Out:
# Index(['GAME_ID', 'EVENTNUM', 'EVENTMSGTYPE', 'EVENTMSGACTIONTYPE', 'PERIOD',
#        'WCTIMESTRING', 'PCTIMESTRING', 'HOMEDESCRIPTION', 'NEUTRALDESCRIPTION',
#        'VISITORDESCRIPTION', 'SCORE', 'SCOREMARGIN', 'PERSON1TYPE',
#        'PLAYER1_ID', 'PLAYER1_NAME', 'PLAYER1_TEAM_ID', 'PLAYER1_TEAM_CITY',
#        'PLAYER1_TEAM_NICKNAME', 'PLAYER1_TEAM_ABBREVIATION', 'PERSON2TYPE',
#        'PLAYER2_ID', 'PLAYER2_NAME', 'PLAYER2_TEAM_ID', 'PLAYER2_TEAM_CITY',
#        'PLAYER2_TEAM_NICKNAME', 'PLAYER2_TEAM_ABBREVIATION', 'PERSON3TYPE',
#        'PLAYER3_ID', 'PLAYER3_NAME', 'PLAYER3_TEAM_ID', 'PLAYER3_TEAM_CITY',
#        'PLAYER3_TEAM_NICKNAME', 'PLAYER3_TEAM_ABBREVIATION',
#        'VIDEO_AVAILABLE_FLAG'],
#       dtype='object')
